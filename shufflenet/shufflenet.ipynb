# %%
import torchvision
import torch
import torch.nn as nn

from torchvision import transforms

from tqdm import tqdm

from shufflenet.model.shufflenetv2 import ShuffleNetV2

# %%
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])
dataset1 = torchvision.datasets.CIFAR10('./data', train=True, download=True,
                                        transform=transform)
dataset2 = torchvision.datasets.CIFAR10('./data', train=False, download=True,
                                        transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
model = ShuffleNetV2(in_channels=3, num_classes=10, classifier_drop=0.2)
print(model)
# Out:
# ShuffleNetV2(
#   (conv1): ConvBNReluLayer(
#     (conv): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): Sequential()
#   )
#   (layers): ModuleList(
#     (0): ShuffleNetDownsampleBlock(
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(24, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=58)
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shortcut): Sequential(
#         (0): ConvBNReluLayer(
#           (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Sequential()
#         )
#         (1): ConvBNReluLayer(
#           (conv): Conv2d(24, 58, kernel_size=(1, 1), stride=(1, 1))
#           (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU()
#         )
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (1): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58)
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (2): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58)
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (3): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58)
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (4): ShuffleNetDownsampleBlock(
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shortcut): Sequential(
#         (0): ConvBNReluLayer(
#           (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Sequential()
#         )
#         (1): ConvBNReluLayer(
#           (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#           (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU()
#         )
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (5): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (6): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (7): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (8): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (9): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (10): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (11): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116)
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (12): ShuffleNetDownsampleBlock(
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=232)
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shortcut): Sequential(
#         (0): ConvBNReluLayer(
#           (conv): Conv2d(232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Sequential()
#         )
#         (1): ConvBNReluLayer(
#           (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#           (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU()
#         )
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (13): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232)
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (14): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232)
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#     (15): ShuffleNetBlock(
#       (split): ChannelSplit()
#       (conv1): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (conv2): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232)
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): Sequential()
#       )
#       (conv3): ConvBNReluLayer(
#         (conv): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU()
#       )
#       (shuffle): ChannelShuffle()
#     )
#   )
#   (conv2): ConvBNReluLayer(
#     (conv): Conv2d(464, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): Sequential()
#   )
#   (classifier): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )

# %%
test_in = torch.rand(1, 3, 224, 224)
print(model(test_in).shape)
# Out:
# torch.Size([1, 10])

# %%
train_params = {
    'epochs': 16,
    'lr': 0.1,
    'eval_portion': 0.2,
    'batch_size': 16
}

device = torch.device('cuda')

# %%
from torch.utils.data import DataLoader, random_split

EVAL_LENGTH = int(len(dataset1) * train_params['eval_portion'])

train_set, eval_set = random_split(dataset1, [len(dataset1) - EVAL_LENGTH, EVAL_LENGTH])
train_loader = DataLoader(train_set, batch_size=train_params['batch_size'],
                          shuffle=True)

eval_loader = DataLoader(eval_set, batch_size=train_params['batch_size'])

test_loader = DataLoader(dataset2, batch_size=train_params['batch_size'],
                         shuffle=True)

# %%
model = model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=train_params['lr'], momentum=0.9, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=0.9)

cross_entropy = nn.CrossEntropyLoss()

best_accuracy = 0.0

for e in range(train_params['epochs']):
    train_loss = 0.0
    model.train()
    for images, labels in tqdm(iter(train_loader), desc='Training...'):
        optimizer.zero_grad()

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = cross_entropy(outputs, labels)
        train_loss += loss.cpu().detach().numpy()

        loss.backward()
        optimizer.step()

    print(f"Training average loss: {train_loss / len(train_loader)}")

    test_acc_count = 0.0
    eval_loss = 0.0

    model.eval()
    with torch.no_grad():
        for images, labels in tqdm(iter(eval_loader), desc='Eval...'):
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = cross_entropy(outputs, labels)
            eval_loss += loss.cpu().detach().numpy()

            pred = torch.argmax(outputs, 1)
            test_acc_count += float(torch.sum(pred == labels))

    test_accuracy = float(test_acc_count) / float(len(eval_set))
    eval_loss /= len(eval_loader)

    print(f'Epoch: {e + 1}, eval accuracy {test_accuracy}, eval loss {eval_loss}')
    if test_accuracy > best_accuracy:
        torch.save(model.state_dict(), 'checkpoints/model.pth')
        best_accuracy = test_accuracy
# Out:
# Training...:   1%|▏         | 36/2500 [00:17<19:51,  2.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 10>()
#      19 outputs = model(images)
#      20 loss = cross_entropy(outputs, labels)
# ---> 21 train_loss += loss.cpu().detach().numpy()
#      23 loss.backward()
#      24 optimizer.step()
#
# KeyboardInterrupt:
